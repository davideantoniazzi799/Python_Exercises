# %% [markdown]
# INTRODUCTION

# %%
#importazione
from matplotlib import pyplot as plt

# %%
x = [25, 26, 27, 28, 29, 30]
y = [100, 90, 120, 140, 120, 150]

# %%
plt.plot(x,y)
plt.show()

#con .plot() andiamo a creare un grafico inserendo i dati tra parentesi. I dati devono avere stessa lunghezza
#ma senza .show() non possiamo visualizzare il grafico. Per questo è importante utilizzarlo!
#Poi nella console di Python saremmo in grado di muoverci nel plot, salvarlo o fare altre cose
